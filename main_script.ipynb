# %%
# %matplotlib inline 
import numpy as np
from dataloader import *
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Dataset

# %%
trainset = CityScapesDataset('./train.csv')
valset = CityScapesDataset('./val.csv')
testset = CityScapesDataset('./test.csv')

# %%
img, target, label = trainset.__getitem__(0)

# %%
plt.imshow(img[0,:,:])
plt.show()
print('The of each image is:', (img.shape[1],img.shape[2]))
print('The number of channels:', img.shape[0])
# Out:
# The of each image is: (1024, 2048)
# The number of channels: 3

# %%
plt.imshow(label)
plt.show()

# %%
# %matplotlib inline 
import numpy as np
from dataloader import *
from PIL import Image
import matplotlib.pyplot as plt


trans = transforms.Compose([transforms.ToTensor()])#,transforms.ToTensor()

trainset = CityScapesDataset('./train.csv', transforms = trans)
valset = CityScapesDataset('./val.csv')
testset = CityScapesDataset('./test.csv')
img, target, label = trainset.__getitem__(0)
plt.imshow(img[0,:,:])
plt.show()
fig = plt.figure()
plt.imshow(label)
plt.show()
print('The of each image is:', (img.shape[1],img.shape[2]))
print('The number of channels:', img.shape[0])
print(img)
# Out:
# label tranforms:  Compose(
#     RandomRotation(degrees=(12, 12), resample=False, expand=False)
#     ToTensor()
# )
# The of each image is: (1024, 2048)
# The number of channels: 3
# tensor([[[-0.8152, -0.8152, -0.8152,  ..., -0.8152, -0.8152, -0.8152],
#          [-0.8152, -0.8152, -0.8152,  ..., -0.8152, -0.8152, -0.8152],
#          [-0.8152, -0.8152, -0.8152,  ..., -0.8152, -0.8152, -0.8152],
#          ...,
#          [-0.8152, -0.8152, -0.8152,  ..., -0.8152, -0.8152, -0.8152],
#          [-0.8152, -0.8152, -0.8152,  ..., -0.8152, -0.8152, -0.8152],
#          [-0.8152, -0.8152, -0.8152,  ..., -0.8152, -0.8152, -0.8152]],
#
#         [[-0.9159, -0.9159, -0.9159,  ..., -0.9159, -0.9159, -0.9159],
#          [-0.9159, -0.9159, -0.9159,  ..., -0.9159, -0.9159, -0.9159],
#          [-0.9159, -0.9159, -0.9159,  ..., -0.9159, -0.9159, -0.9159],
#          ...,
#          [-0.9159, -0.9159, -0.9159,  ..., -0.9159, -0.9159, -0.9159],
# ...
